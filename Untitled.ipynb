# %%
# !mlflow ui
# Out:
# [2020-01-23 11:24:26 +0000] [16035] [INFO] Starting gunicorn 20.0.4
# [2020-01-23 11:24:26 +0000] [16035] [INFO] Listening at: http://127.0.0.1:5000 (16035)
# [2020-01-23 11:24:26 +0000] [16035] [INFO] Using worker: sync
# [2020-01-23 11:24:26 +0000] [16038] [INFO] Booting worker with pid: 16038
# 2020/01/23 11:43:13 ERROR mlflow.server: Exception on /ajax-api/2.0/preview/mlflow/model-versions/search [GET]
# Traceback (most recent call last):
#   File "/home/pedro/anaconda3/envs/py36/lib/python3.6/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/pedro/anaconda3/envs/py36/lib/python3.6/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/pedro/anaconda3/envs/py36/lib/python3.6/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
# ...
